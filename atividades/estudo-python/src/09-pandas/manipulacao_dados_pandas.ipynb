# %% [markdown]
# ## Importação da biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# ## Convertendo o dataset tsv para csv

# %%
import csv
with open('../09-pandas/datasets/2004-2021.tsv', 'r') as entrada, open('../09-pandas/datasets/2004-2021.csv', 'w', newline='') as saida:
    escrever = csv.writer(saida)
    for row in csv.reader(entrada, delimiter='\t'):
        escrever.writerow(row)

# %% [markdown]
# ## Importando o Dataset

# %%
# carregando dataset com separador sep =','
data = pd.read_csv('../09-pandas/datasets/2004-2021.csv',sep=',')

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## Mostrando as primeiras linhas do Dataset

# %%
## mostras as 10 primeiras linhas do dataframe
data.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# ...

# %% [markdown]
# ## Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  str
#  1   DATA FINAL                     120823 non-null  str
#  2   REGIÃO                         120823 non-null  str
#  3   ESTADO                         120823 non-null  str
#  4   PRODUTO                        120823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  str
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  str
# ...

# %% [markdown]
# ## Data Frame

# %%
type(data)
# Out:
# pandas.DataFrame

# %% [markdown]
# ### podemos acessar as **dimensões do Data Frame** utilizando o atributo .shape do Data Frame

# %%
data.shape
# Out:
# (120823, 18)

# %%
print(f'O DataFrame possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atributos/variáveis.')
# Out:
# O DataFrame possui 120823 linhas/observações/registros e 18 colunas/atributos/variáveis.

# %% [markdown]
# ## Criando um DataFrame

# %% [markdown]
# Um novo DataFrame pode ser criado a partir de um dicionário, onde cada chave possui uma linha de elementos de igual tamanho.
#     As chaves representam as colunas e cada um dos valores de sua lista representa o valor da linha correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['José da Silva', 'Yoda', 'Luke Skywalker'] ,
    'idade': [50, 100, 20] ,
    'peso': [70.3, 15.8, 60.5] ,
    'eh jedi': [False, True, True] # nomes nas colunas pode ter espaço
})

# %%
personagens_df
# Out:
#     NOME COMPLETO  IDADE  PESO  EH JEDI
# 0   José da Silva     50  70.3    False
# 1            Yoda    100  15.8     True
# 2  Luke Skywalker     20  60.5     True

# %%
personagens_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NOME COMPLETO  3 non-null      str
#  1   IDADE          3 non-null      int64
#  2   PESO           3 non-null      float64
#  3   EH JEDI        3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), str(1)
# memory usage: 207.0 bytes

# %% [markdown]
# ## Renomeando as colunas de um DataFrame

# %% [markdown]
# O atributo DataFrame.columns retorna uma lista com os nomes de todas as colunas do data frame.

# %%
personagens_df.columns
# Out:
# Index(['NOME COMPLETO', 'IDADE', 'PESO', 'EH JEDI'], dtype='str')

# %%
# converte para uma lista 
list(personagens_df.columns)
# Out:
# ['NOME COMPLETO', 'IDADE', 'PESO', 'EH JEDI']

# %% [markdown]
# ===> Para renomear colunas do data frame, utilizamos o método DataFrame.rename, que retorna uma cópia do data frame com as colunas renomeadas:

# %%
personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade',
    'peso': 'Peso',
    'eh jedi': 'Eh Jedi'
})
# Out:
#     NOME COMPLETO  IDADE  PESO  EH JEDI
# 0   José da Silva     50  70.3    False
# 1            Yoda    100  15.8     True
# 2  Luke Skywalker     20  60.5     True

# %%
personagens_df
# Out:
#     NOME COMPLETO  IDADE  PESO  EH JEDI
# 0   José da Silva     50  70.3    False
# 1            Yoda    100  15.8     True
# 2  Luke Skywalker     20  60.5     True

# %% [markdown]
# ### para alterar os valores originais usamos inplace = True

# %%
personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade',
    'peso': 'Peso',
    'eh jedi': 'Eh Jedi'
}, inplace = True)

# %%
personagens_df
# Out:
#     NOME COMPLETO  IDADE  PESO  EH JEDI
# 0   José da Silva     50  70.3    False
# 1            Yoda    100  15.8     True
# 2  Luke Skywalker     20  60.5     True

# %% [markdown]
# ### renomear todas as colunas de uma única vez

# %%
lista = [ x.upper() for x in list(personagens_df.columns) ]
personagens_df.columns = lista
personagens_df
# Out:
#     NOME COMPLETO  IDADE  PESO  EH JEDI
# 0   José da Silva     50  70.3    False
# 1            Yoda    100  15.8     True
# 2  Luke Skywalker     20  60.5     True

# %% [markdown]
# ## Series

# %% [markdown]
# Uma Series é um array unidimensional com os dados e rótulos de um eixo do dataset.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# selecionando uma coluna inteira
data['ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: str

# %%
# Selecionando uma coluna inteira de outra forma , acessando pelo ' . '
# ATENÇÃO -> Só funciona se não tiver espaços ou caracteres especiais, como acentos.
data.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: str

# %%
type(data['ESTADO'])
# Out:
# pandas.Series

# %%
# Selecionando a observação de uma linha do DataFrame
data.iloc[1]
# Out:
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# Name: 1, dtype: object

# %%
type(data.iloc[100])
# Out:
# pandas.Series

# %% [markdown]
# ## Criando uma Series

# %% [markdown]
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.4, 6, 9.9999])
# Out:
# 0    5.4000
# 1    6.0000
# 2    9.9999
# dtype: float64

# %% [markdown]
# ### Alterando o nome dos indices e o nome da Series

# %%
pd.Series( [5.5, 6.3, 8.9], index=['Prova 1', 'Prova 2', 'Projeto Final'], name = 'Notas do Luke Skywalker' )
# Out:
# Prova 1          5.5
# Prova 2          6.3
# Projeto Final    8.9
# Name: Notas do Luke Skywalker, dtype: float64

# %% [markdown]
# ## Atribuindo Dados

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ### Atribuindo constantes

# %%
produto_view_referencia = data['PRODUTO']
produto_view_referencia
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: str

# %% [markdown]
# Para fazer uma cópia é necessário passar o método copy() para esse data frame

# %%
produto_copia = data['PRODUTO'].copy()

# %%
produto_copia
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: str

# %% [markdown]
# ### Atenção

# %% [markdown]
# Caso faça:
# ```bash
#     produto = data['PRODUTO'] # produto é apenas referencia
#     data['PRODUTO'] = 'Combustível' # altera todos os valores que estão em PRODUTO para Combustível
# ```
# Temos que produto é apenas uma referencia , ou seja caso não queiramos alterar diretamente os valores de nosso data frame devemos fazer uma cópia do mesmo para uma nova variáveil usando o comando copy() não perdendo valores e preservando o data frame original.

# %% [markdown]
# ### Atribuindo uma Series ou Lista de valores

# %%
# deve ser passar a mesma quantidade esperada de valores que já estão em nosso data frame
nLinhas, nColunas = data.shape
nLinhas, nColunas
# Out:
# (120823, 18)

# %%
novos_produtos = [ f'Produto {i}' for i in range(nLinhas) ]
len(novos_produtos)
# Out:
# 120823

# %% [markdown]
# Agora vamos alterar e ver como fica o resultado

# %%
data['PRODUTO'] = novos_produtos
data['PRODUTO'].head()
# Out:
# 0    Produto 0
# 1    Produto 1
# 2    Produto 2
# 3    Produto 3
# 4    Produto 4
# Name: PRODUTO, dtype: str

# %% [markdown]
# Note que na nossa variável apenas de referência eles também foram copiados

# %%
produto_view_referencia
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: str

# %%
# comparando a referência com a cópia
print(produto_view_referencia)
print('\n')
print(produto_copia)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: str
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: str

# %% [markdown]
# Voltando aos valores padrões

# %%
data['PRODUTO'] = produto_copia
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## Criando novas colunas
# Para criar uma nova coluna no data frame , atribuímos uma lista ou Series ou uma constante a uma nova chave no 'data frame'.
# A quantidade de valores da lista precisa ser igual ao número de linhas/registros do data frame

# %%
# criando uma nova coluna no data frame , como iremos fazer isso apenas para facilitar 
# irei criar uma cópia de nosso DataFrame original
data_copia = data.copy()
data_copia
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ### Criando uma coluna a partir de um valor constante

# %%
data['NOVA COLUNA'] = 'DEFAULT'
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# Ao criar o comando eu digitei duas vezes e com isso temos duas colunas novas, uma que se chama 'Nova Coluna' e outra que se chama 'NOVA COLUNA', com isso temos um produto semântico , que devemos resolver apagando uma das colunas novas usando o comando drop()

# %%
data = data.drop(columns=['Nova Coluna'])
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data = data.drop(columns=['Nova Coluna'])
#       2 data
#
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
# ...

# %% [markdown]
# ### Atribuindo intervalo de valores para uma nova coluna

# %%
data['INTERVALO DE VALORES'] = range(data.shape[0])
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ### Atribuindo uma Series a uma nova coluna no dataframe

# %%
# verificar se os valores são do mesmo tipo
print(data['PREÇO MÉDIO DISTRIBUIÇÃO'].dtypes)

# realizar a conversão para o tipo adequado
data['PREÇO MÉDIO DISTRIBUIÇÃO'] = pd.to_numeric(data['PREÇO MÉDIO DISTRIBUIÇÃO'], errors='coerce')

data['PREÇO MÉDIO DISTRIBUIÇÃO EM DÓLAR'] = data['PREÇO MÉDIO DISTRIBUIÇÃO'] * 5.10
data
# Out:
# str
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## Índices

# %% [markdown]
# Todo dataframe possui índices que não são considerados colunas da tabela. Eles podem ser numéricos indo de zero até quantidade de linha menos um , mas também podem ser do tipo textual (rótulos / labels)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=120823, step=1)

# %%
# criar uma lista a partir do data.index
lista = list(data.index) 
# ou 
lista = data.index.to_list()
len(lista)
# Out:
# 120823

# %% [markdown]
# ### Exemplo de DataFrame com índices textuais ( labels )

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30], 
    'pessimo': [30, 20, 1]
}, index = ['XboxOne', 'Playstation4', 'Switch'])
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %% [markdown]
# ### Selecionando uma ou mais observações (Indexação)

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %% [markdown]
# ## ==> index based selection (Seleção baseada em índices)
# iloc -> seleciona elementos do DataFrame, baseado em seu índice , sendo primeiro a linha e depois a coluna

# %% [markdown]
# #### Selecionando uma observação / registro / linha

# %%
data.iloc[1]
# Out:
# DATA INICIAL                               2004-05-09
# DATA FINAL                                 2004-05-15
# REGIÃO                                   CENTRO OESTE
# ESTADO                                          GOIAS
# PRODUTO                              ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                      387
# UNIDADE DE MEDIDA                                R$/l
# PREÇO MÉDIO REVENDA                             1.162
# DESVIO PADRÃO REVENDA                           0.114
# PREÇO MÍNIMO REVENDA                             0.89
# PREÇO MÁXIMO REVENDA                            1.449
# MARGEM MÉDIA REVENDA                            0.399
# COEF DE VARIAÇÃO REVENDA                        0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                        0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                      0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                      0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                        1.05
# ...

# %% [markdown]
# Mostra a amostra na linha 1 ou registro 1

# %% [markdown]
# ### Selecionando múltiplas observações / linhas contínuas

# %%
# selecionando as linhas de 0 a 5 inclusive
data.iloc[:6,] # é o usado a técnica do slice do python não precisa colocar o zero pois é o primeiro índice
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
# ...

# %% [markdown]
# ### Selecionando itens de uma lista de indices

# %%
data.iloc[[1,3,5,7,9]]
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1  ETANOL HIDRATADO                           387              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1                1.162                  0.114                 0.890  ...
# ...

# %% [markdown]
# ### Selecionando itens usando uma função lambda

# %%
data.iloc[lambda x: (x.index % 2 == 0) & (x.index < 10)]
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
# 4   2004-05-09  2004-05-15      NORDESTE           ALAGOAS  ETANOL HIDRATADO
# 6   2004-05-09  2004-05-15      NORDESTE             CEARA  ETANOL HIDRATADO
# 8   2004-05-09  2004-05-15      NORDESTE           PARAIBA  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 2                           192              R$/l                1.389
# 4                           103              R$/l                1.181
# 6                           278              R$/l                1.453
# 8                           125              R$/l                1.284
#
# ...

# %% [markdown]
# ### Retornando uma  linha e coluna ( linha == 1 , coluna == 3)

# %%
data.iloc[1,3]
# Out:
# 'GOIAS'

# %% [markdown]
# ## ==> label based selection (Seleção baseada em rótulos)
# loc faz a seleção dos elementos do Dataframe, baseaso em rótulos --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# usando o método loc -> retorna a linha cujo índice é XboxOne
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %% [markdown]
# ### Não funciona
# iloc -> acessar índices com rótulos

# %%
pesquisa_de_satisfacao.iloc['XboxOne']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 pesquisa_de_satisfacao.iloc['XboxOne']
#
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/indexing.py:1770, in _iLocIndexer._getitem_axis(self, key, axis)
#    1768 key = item_from_zerodim(key)
#    1769 if not is_integer(key):
# -> 1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
#    1773 self._validate_integer(key, axis)
#
# ...

# %% [markdown]
# ### Não funciona
# loc acessar índices

# %%
pesquisa_de_satisfacao.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 pesquisa_de_satisfacao.loc[0]
#
# ...

# %% [markdown]
# ### Acessar dados usando iloc e loc dentro do Dataframe

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %% [markdown]
# ### pessoas que acharam o Playstation4 ruim

# %%
pesquisa_de_satisfacao.loc['Playstation4','ruim']
# Out:
# np.int64(2)

# %% [markdown]
# ### sub tabela do Dataframe

# %%
pesquisa_de_satisfacao.loc[['Switch', 'XboxOne']]
# Out:
#          bom  ruim  pessimo
# Switch   100    30        1
# XboxOne   50   131       30

# %% [markdown]
# ### todas as linhas onde o produto é considerado ruim, péssimo

# %%
pesquisa_de_satisfacao.loc[:, ['ruim', 'pessimo']]
# Out:
#               ruim  pessimo
# XboxOne        131       30
# Playstation4     2       20
# Switch          30        1

# %% [markdown]
# ## Observação
# **Índices Númericos** por default, possuem rótulos que correspondem aos seus valores

# %%
data.loc[100]
# Out:
# DATA INICIAL                               2004-05-30
# DATA FINAL                                 2004-06-05
# REGIÃO                                          NORTE
# ESTADO                                      TOCANTINS
# PRODUTO                              ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                       73
# UNIDADE DE MEDIDA                                R$/l
# PREÇO MÉDIO REVENDA                             1.268
# DESVIO PADRÃO REVENDA                           0.101
# PREÇO MÍNIMO REVENDA                            1.099
# PREÇO MÁXIMO REVENDA                             1.58
# MARGEM MÉDIA REVENDA                            0.572
# COEF DE VARIAÇÃO REVENDA                         0.08
# PREÇO MÉDIO DISTRIBUIÇÃO                        0.696
# DESVIO PADRÃO DISTRIBUIÇÃO                      0.102
# PREÇO MÍNIMO DISTRIBUIÇÃO                       0.554
# PREÇO MÁXIMO DISTRIBUIÇÃO                      0.9612
# ...

# %% [markdown]
# ## Selecionando um ou mais atributos ( colunas )

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data['ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: str

# %%
data.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: str

# %%
data.loc[:, ['ESTADO']]
# Out:
#                     ESTADO
# 0         DISTRITO FEDERAL
# 1                    GOIAS
# 2              MATO GROSSO
# 3       MATO GROSSO DO SUL
# 4                  ALAGOAS
# ...                    ...
# 120818             RORAIMA
# 120819      SANTA CATARINA
# 120820           SAO PAULO
# 120821             SERGIPE
# 120822           TOCANTINS
#
# [120823 rows x 1 columns]

# %% [markdown]
# ### Atenção
# O acesso a uma coluna utilizando o nome_da_coluna, só funciona se não tiver caracteres considerados inválidos, tais como espaço, acentuação, c cedilha, etc..
# Nesse caso devemos usar apenas a seleção via string

# %%
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 120818    2021-04-25
# 120819    2021-04-25
# 120820    2021-04-25
# 120821    2021-04-25
# 120822    2021-04-25
# Name: DATA INICIAL, Length: 120823, dtype: str

# %% [markdown]
# ### Selecionando múltiplas colunas

# %%
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO              ESTADO        REGIÃO
# 0       ETANOL HIDRATADO    DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO               GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO         MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO  MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO             ALAGOAS      NORDESTE
# ...                  ...                 ...           ...
# 120818   OLEO DIESEL S10             RORAIMA         NORTE
# 120819   OLEO DIESEL S10      SANTA CATARINA           SUL
# 120820   OLEO DIESEL S10           SAO PAULO       SUDESTE
# 120821   OLEO DIESEL S10             SERGIPE      NORDESTE
# 120822   OLEO DIESEL S10           TOCANTINS         NORTE
#
# [120823 rows x 3 columns]

# %% [markdown]
# ## ==> Label-based selection ( seleção baseada em rótulos )

# %% [markdown]
# loc: seleciona os elementos do dataframe baseado em seus rótulos --> row first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna a linha de índice 0 (implícito) --> usando o iloc
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# retorna o valor da linha de início 0 ( implícito ) e coluna de indíce 1 ( implicito ) --> usando o iloc
pesquisa_de_satisfacao.iloc[0 ,1]
# Out:
# np.int64(131)

# %%
# retorna a linha cujo o rótulo do índice é XboxOne
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# Não funciona 
pesquisa_de_satisfacao.iloc['XboxOne']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 2
#       1 # Não funciona
# ----> 2 pesquisa_de_satisfacao.iloc['XboxOne']
#
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/indexing.py:1770, in _iLocIndexer._getitem_axis(self, key, axis)
#    1768 key = item_from_zerodim(key)
#    1769 if not is_integer(key):
# -> 1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
#    1773 self._validate_integer(key, axis)
#
# ...

# %%
# Não funciona -- loc tetando acessar o indice
pesquisa_de_satisfacao.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/lipai_ufu/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 2
#       1 # Não funciona -- loc tetando acessar o indice
# ----> 2 pesquisa_de_satisfacao.loc[0]
#
# ...

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# mostra a quantidade de dados da pesquisa para uma determinada linha e coluna
pesquisa_de_satisfacao.loc['Playstation4', 'pessimo']
# Out:
# np.int64(20)

# %%
# selecionando as linhas de índice rotulados XboxOne, Switch
pesquisa_de_satisfacao.loc[['XboxOne','Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'ruim'
pesquisa_de_satisfacao.loc[:,['bom','ruim']]
# Out:
#               bom  ruim
# XboxOne        50   131
# Playstation4   21     2
# Switch        100    30

# %% [markdown]
# ## Selecionando um ou mais atributos ( colunas )

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
# retornando a coluna/ atributo 'ESTADO'
data['ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: str

# %%
data.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: str

# %%
data.loc[:, 'ESTADO']

# %%
 ### Atenção:
 #   No caso de strings com acentuação , espaços, caracteres especiais , não tem como acessar utilizando 
# diretamente o método ponto.
data.DATA INICIAL
# Out:
#   Cell In[121], line 4
#     data.DATA INICIAL
#               ^
# SyntaxError: invalid syntax

# %%
# Para esses casos iremos utilizar sempre a passagem da string 
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 120818    2021-04-25
# 120819    2021-04-25
# 120820    2021-04-25
# 120821    2021-04-25
# 120822    2021-04-25
# Name: DATA INICIAL, Length: 120823, dtype: str

# %%
# selecionando múltiplas colunas
data[['PRODUTO','ESTADO','REGIÃO']]
# Out:
#                  PRODUTO              ESTADO        REGIÃO
# 0       ETANOL HIDRATADO    DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO               GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO         MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO  MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO             ALAGOAS      NORDESTE
# ...                  ...                 ...           ...
# 120818   OLEO DIESEL S10             RORAIMA         NORTE
# 120819   OLEO DIESEL S10      SANTA CATARINA           SUL
# 120820   OLEO DIESEL S10           SAO PAULO       SUDESTE
# 120821   OLEO DIESEL S10             SERGIPE      NORDESTE
# 120822   OLEO DIESEL S10           TOCANTINS         NORTE
#
# [120823 rows x 3 columns]

# %% [markdown]
# ## Removendo um Atributo (Coluna) do Data Frame

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %% [markdown]
# Vamos remover do nosso data set a coluna 'NOVA COLUNA', pois tem apenas valores DEFAULT.

# %% [markdown]
# ### Deleta / remove in-place ( ou seja no próprio dataframe ) a coluna de rótulo 'NOVA COLUNA'

# %%
del data['NOVA COLUNA']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# <br> Removendo a coluna 'PREÇO MÉDIO DISTRIBUIÇÃO EM DÓLAR' </br>

# %%
del data['PREÇO MÉDIO DISTRIBUIÇÃO EM DÓLAR']
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ## Salvando um Data Frame
# Para salvar um Data Frame , usamos o método __.to_csv__.
# Por padrão, esse método __salva os índices das tabelas como uma coluna no CSV.__
# Por padrão, o método utilizará, ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro sep.

# %%
data.to_csv('./datasets/precosCombustiveis.csv', index=False)

# %% [markdown]
# ### salvando com índice igual a True

# %%
data.to_csv('./datasets/precosCombustiveisComIndiceIgualATrue.csv', index=True)

# %% [markdown]
# ## Seleção condicional: Filtrando amostras
# Existem algumas maneiras de filtrarmos os dados de nossa amostra.
# Mas primeiro vamos carregar os dados salvos anteriormente.

# %%
data = pd.read_csv('./datasets/precosCombustiveis.csv')

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# mostra valores únicos de uma coluna de nosso dataset
data['ESTADO'].unique()

# %% [markdown]
# ### Selecionando apenas os preços dos Postos do 'RIO GRANDE DO SUL'

# %% [markdown]
# ### ===> 1- Usando seleção condicional ( Comparações diretas )
# O código abaixo retorna a Series (' array ') com o número de linhas ( observações ) do Data Frame , que informa o registro de preços dos postos do estado do RIO GRANDE DO SUL ( TRUE )

# %%
# Faz a comparação elemento a elemento da SERIES retornando uma Series de booleans
data['ESTADO'] == 'RIO GRANDE DO SUL'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Name: ESTADO, Length: 120823, dtype: bool

# %%
# Salvando a series de booleans na variável selecao
selecao = data['ESTADO'] == 'RIO GRANDE DO SUL'

# %%
# mostra apenas os últimos dados
print(selecao.tail())
# mostra o tipo de dado
print(type(selecao))
# mostra a quantidade de linhas
print(selecao.shape)
# mostra a mesma quantidade para fins de comparação
print(data.shape)
# Out:
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Name: ESTADO, dtype: bool
# <class 'pandas.Series'>
# (120823,)
# (120823, 19)

# %% [markdown]
# Filtrando os postos do estado do RIO GRANDE DO SUL

# %%
# mostra apenas os dados verdadeiros que correspondem a selecao 
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 25       2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 52       2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 79       2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 106      2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 133      2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# ...             ...         ...    ...                ...               ...
# 120719   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL    GASOLINA COMUM
# 120746   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GLP
# 120765   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GNV
# 120789   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL       OLEO DIESEL
# 120816   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL   OLEO DIESEL S10
#
# ...

# %% [markdown]
# O resultado é um Data Frame com apenas os registros filtrados através da variável selecao.
#
# Podemos ainda utilizar o método __loc__ com o mesmo fim.

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 25       2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 52       2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 79       2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 106      2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 133      2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# ...             ...         ...    ...                ...               ...
# 120719   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL    GASOLINA COMUM
# 120746   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GLP
# 120765   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GNV
# 120789   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL       OLEO DIESEL
# 120816   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL   OLEO DIESEL S10
#
# ...

# %% [markdown]
# Também podemos utilizar o formato abaixo para obtermos o mesmo resultado, nesse caso não guardamos o valor do Data Frame em uma variável, mostrando diretamente os dados, entretanto dessa forma não iremos poder trabalhar com a variável selecao

# %%
data[data['ESTADO'] == 'RIO GRANDE DO SUL'].head()
# Out:
#     DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 25    2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 52    2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 79    2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 106   2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 133   2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 25                            689              R$/l                1.224
# 52                            674              R$/l                1.220
# 79                            690              R$/l                1.235
# 106                           686              R$/l                1.333
# 133                           698              R$/l                1.358
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### ===> 2- Usando o método Query
# Query filtra linhas de um DataFrame baseado em query ( pergunta ).

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data.query('ESTADO == "RIO GRANDE DO SUL"')
# Out:
#        DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 25       2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 52       2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 79       2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 106      2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 133      2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# ...             ...         ...    ...                ...               ...
# 120719   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL    GASOLINA COMUM
# 120746   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GLP
# 120765   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GNV
# 120789   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL       OLEO DIESEL
# 120816   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL   OLEO DIESEL S10
#
# ...

# %% [markdown]
# ### Atenção:
# Uma boa prática ao investigarmos os dados é salvar em uma varíavel

# %%
# salva em memória na variável postos_RS
postos_RS = data.query('ESTADO == "RIO GRANDE DO SUL" ')

# %%
postos_RS.head()
# Out:
#     DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 25    2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 52    2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 79    2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 106   2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 133   2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 25                            689              R$/l                1.224
# 52                            674              R$/l                1.220
# 79                            690              R$/l                1.235
# 106                           686              R$/l                1.333
# 133                           698              R$/l                1.358
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### Reset dos índices do Data Frame original
# Algumas vezes precisamos dar um reset no índice , ou seja iniciar novamente do zero, devemos analisar quando isso é necessário, talvez quando queremos um novo subset ou salvar apenas os dados daquele ESTADO em um novo csv.
# Usamos o método .reset_index() que não altera a nossa variável

# %%
postos_RS.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL REGIÃO             ESTADO  \
# 0         25   2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL
# 1         52   2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL
# 2         79   2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL
# 3        106   2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL
# 4        133   2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL
# ...      ...          ...         ...    ...                ...
# 4814  120719   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL
# 4815  120746   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL
# 4816  120765   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL
# 4817  120789   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL
# 4818  120816   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                           689              R$/l
# ...

# %% [markdown]
# Podemos notar que nossa primeira linha corresponde a um novo índice aquele que foi criado usando o método .reset_index(), entretanto ainda temos na nossa variável o índice original , caso não queiramos isso , podemos passar o parâmetro drop.

# %%
postos_RS.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# ...           ...         ...    ...                ...               ...
# 4814   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL    GASOLINA COMUM
# 4815   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GLP
# 4816   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GNV
# 4817   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL       OLEO DIESEL
# 4818   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL   OLEO DIESEL S10
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Os dados de postos_RS ainda não foram alterados , visto que o resultado é apenas uma cópia, para realizarmos a alteração definitiva da variável , devemos recorrer ao in place.

# %%
# postos do RIO GRANDE DO SUL, sem alteração
postos_RS.head()
# Out:
#     DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 25    2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 52    2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 79    2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 106   2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 133   2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 25                            689              R$/l                1.224
# 52                            674              R$/l                1.220
# 79                            690              R$/l                1.235
# 106                           686              R$/l                1.333
# 133                           698              R$/l                1.358
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
postos_RS.reset_index(drop=True, inplace=True)

# %%
postos_RS
# Out:
#      DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# ...           ...         ...    ...                ...               ...
# 4814   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL    GASOLINA COMUM
# 4815   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GLP
# 4816   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL               GNV
# 4817   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL       OLEO DIESEL
# 4818   2021-04-25  2021-05-01    SUL  RIO GRANDE DO SUL   OLEO DIESEL S10
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### ===> 3- Fazendo tudo em apenas uma linha (single line code).

# %%
postos_RS = data.query('ESTADO == "RIO GRANDE DO SUL"').reset_index(drop=True, inplace=False)

# %%
postos_RS.head()
# Out:
#   DATA INICIAL  DATA FINAL REGIÃO             ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 1   2004-05-16  2004-05-22    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 2   2004-05-23  2004-05-29    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 3   2004-05-30  2004-06-05    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
# 4   2004-06-06  2004-06-12    SUL  RIO GRANDE DO SUL  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           689              R$/l                1.224
# 1                           674              R$/l                1.220
# 2                           690              R$/l                1.235
# 3                           686              R$/l                1.333
# 4                           698              R$/l                1.358
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### Selecionando registros de postos do Rio de Janeiro com preços acima de 2 reais.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data["ESTADO"].unique()
# Out:
# <StringArray>
# [   'DISTRITO FEDERAL',               'GOIAS',         'MATO GROSSO',
#   'MATO GROSSO DO SUL',             'ALAGOAS',               'BAHIA',
#                'CEARA',            'MARANHAO',             'PARAIBA',
#           'PERNAMBUCO',               'PIAUI', 'RIO GRANDE DO NORTE',
#              'SERGIPE',                'ACRE',               'AMAPA',
#             'AMAZONAS',                'PARA',            'RONDONIA',
#              'RORAIMA',           'TOCANTINS',      'ESPIRITO SANTO',
#         'MINAS GERAIS',      'RIO DE JANEIRO',           'SAO PAULO',
#               'PARANA',   'RIO GRANDE DO SUL',      'SANTA CATARINA']
# Length: 27, dtype: str

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Name: ESTADO, Length: 120823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818     True
# 120819     True
# 120820     True
# 120821     True
# 120822     True
# Name: PREÇO MÉDIO REVENDA, Length: 120823, dtype: bool

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)

# %% [markdown]
# ### Atenção:
# Note que o __AND__ em python para o pandas é o __&__ , o __OR__ é o __|__ e o NOT é o __~__

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 120717   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 120744   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO               GLP
# 120763   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO               GNV
# 120787   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO       OLEO DIESEL
# 120814   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO   OLEO DIESEL S10
#
# ...

# %% [markdown]
# Podemos usar o método __.query()__ mas o mesmo não irá funcionar nessa caso pois o rótulo ( PREÇO MÉDIO DE REVENDA ), possui caracteres inválidos o **ç** e o **´**.
# Vamos mostrar um exemplo abaixo usando o método .query() para um caso sem problemas, por exemplo no rótulo ( UNIDADE DE MEDIDA ).

# %%
postos_vendem_gas_RJ = data.query('ESTADO == "RIO DE JANEIRO" and (PRODUTO == "GNV" or PRODUTO == "GLP")')

# %%
postos_vendem_gas_RJ
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO PRODUTO  \
# 24154    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO     GLP
# 24181    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO     GLP
# 24208    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO     GLP
# 24235    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO     GLP
# 24262    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO     GLP
# ...             ...         ...      ...             ...     ...
# 120407   2021-04-11  2021-04-17  SUDESTE  RIO DE JANEIRO     GNV
# 120565   2021-04-18  2021-04-24  SUDESTE  RIO DE JANEIRO     GLP
# 120585   2021-04-18  2021-04-24  SUDESTE  RIO DE JANEIRO     GNV
# 120744   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO     GLP
# 120763   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO     GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 24154                            385           R$/13Kg               29.154
# ...

# %% [markdown]
# Caso o Data Frame seja muito grande a abordagem deverá ser feita em partes para diminuir a lentidão da query().

# %%
apenas_estado_rj = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[apenas_estado_rj]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 120717   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 120744   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO               GLP
# 120763   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO               GNV
# 120787   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO       OLEO DIESEL
# 120814   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO   OLEO DIESEL S10
#
# ...

# %%
preco_medio = postos_rj['PREÇO MÉDIO REVENDA'] > 2
preco_medio
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 120717     True
# 120744     True
# 120763     True
# 120787     True
# 120814     True
# Name: PREÇO MÉDIO REVENDA, Length: 4819, dtype: bool

# %%
postos_rj_maior_2 = postos_rj[preco_medio]
postos_rj_maior_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 120717   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 120744   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO               GLP
# 120763   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO               GNV
# 120787   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO       OLEO DIESEL
# 120814   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO   OLEO DIESEL S10
#
# ...

# %% [markdown]
# ### Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina comum acima de 2 reais
# Podemos fazer uma solução 'mais lenta' , percorrendo o DataFrame inteiro múltiplas vezes.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao_1
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao_2
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)
selecao_3
selecao_final = selecao_1 & selecao_2 & selecao_3
selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818    False
# 120819    False
# 120820    False
# 120821    False
# 120822    False
# Length: 120823, dtype: bool

# %%
data[selecao_final]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 120366   2021-04-11  2021-04-17  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120538   2021-04-18  2021-04-24  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120544   2021-04-18  2021-04-24  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120717   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120723   2021-04-25  2021-05-01  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_filtrado = data[selecao_final]
print(data_filtrado.ESTADO.unique())
print(data_filtrado.PRODUTO.unique())
# Out:
# <StringArray>
# ['RIO DE JANEIRO', 'SAO PAULO']
# Length: 2, dtype: str
# <StringArray>
# ['GASOLINA COMUM']
# Length: 1, dtype: str

# %% [markdown]
# ### Maneira mais rápida de fazer

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
# apenas postos de rj e sp
postos_sp_rj = data[selecao_1]
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
selecao_2
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]
# apenas produtos de sp ou rj que são gasolina comum 
postos_sp_rj_gasolina
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 120366   2021-04-11  2021-04-17  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120538   2021-04-18  2021-04-24  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120544   2021-04-18  2021-04-24  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120717   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120723   2021-04-25  2021-05-01  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
selecao_3 = postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2
postos_sp_rj_gasolina_maior_2 = postos_sp_rj_gasolina[selecao_3]
postos_sp_rj_gasolina_maior_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 120366   2021-04-11  2021-04-17  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120538   2021-04-18  2021-04-24  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120544   2021-04-18  2021-04-24  SUDESTE       SAO PAULO  GASOLINA COMUM
# 120717   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 120723   2021-04-25  2021-05-01  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### Selecionando registros dos anos 2017, 2019, 2021

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# Nossos dados não tem a coluna ANO, vamos acrescentar a mesma e depois fazer a filtragem, para isso teremos que transforma a data inicial e data final em um objeto do tipo datetime , fazer a conta do ano e acrescentar o mesmo no nosso DataFrame

# %%
# transforma as colunas DATA INICIAL E DATA FINAL em um objeto datetime
data['DATA INICIAL'] = pd.to_datetime(data['DATA INICIAL'])
data['DATA FINAL'] = pd.to_datetime(data['DATA FINAL'])
data['ANO'] = data['DATA INICIAL'].dt.year
data.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
# ...

# %% [markdown]
# ### Alternativa 1 de filtragem dos anos

# %%
selecao = (data['ANO'] == 2017) |(data['ANO'] == 2019) | (data['ANO'] == 2021) 
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 120818     True
# 120819     True
# 120820     True
# 120821     True
# 120822     True
# Name: ANO, Length: 120823, dtype: bool

# %%
print(data[selecao].ANO.unique())
data[selecao]
# Out:
# [2017 2019 2021]
#        DATA INICIAL DATA FINAL    REGIÃO          ESTADO           PRODUTO  \
# 87256    2017-01-01 2017-01-07     NORTE            ACRE  ETANOL HIDRATADO
# 87257    2017-01-01 2017-01-07  NORDESTE         ALAGOAS  ETANOL HIDRATADO
# 87258    2017-01-01 2017-01-07     NORTE           AMAPA  ETANOL HIDRATADO
# 87259    2017-01-01 2017-01-07     NORTE        AMAZONAS  ETANOL HIDRATADO
# 87260    2017-01-01 2017-01-07  NORDESTE           BAHIA  ETANOL HIDRATADO
# ...             ...        ...       ...             ...               ...
# 120818   2021-04-25 2021-05-01     NORTE         RORAIMA   OLEO DIESEL S10
# 120819   2021-04-25 2021-05-01       SUL  SANTA CATARINA   OLEO DIESEL S10
# 120820   2021-04-25 2021-05-01   SUDESTE       SAO PAULO   OLEO DIESEL S10
# 120821   2021-04-25 2021-05-01  NORDESTE         SERGIPE   OLEO DIESEL S10
# 120822   2021-04-25 2021-05-01     NORTE       TOCANTINS   OLEO DIESEL S10
#
# ...

# %% [markdown]
# ### Alternativa 2 -> lista com os anos 2017, 2019, 2021

# %%
lista_anos = [2017, 2019, 2021]
selecao = data['ANO'].isin(lista_anos) # retorna series de booleanos
data[selecao]
# Out:
#        DATA INICIAL DATA FINAL    REGIÃO          ESTADO           PRODUTO  \
# 87256    2017-01-01 2017-01-07     NORTE            ACRE  ETANOL HIDRATADO
# 87257    2017-01-01 2017-01-07  NORDESTE         ALAGOAS  ETANOL HIDRATADO
# 87258    2017-01-01 2017-01-07     NORTE           AMAPA  ETANOL HIDRATADO
# 87259    2017-01-01 2017-01-07     NORTE        AMAZONAS  ETANOL HIDRATADO
# 87260    2017-01-01 2017-01-07  NORDESTE           BAHIA  ETANOL HIDRATADO
# ...             ...        ...       ...             ...               ...
# 120818   2021-04-25 2021-05-01     NORTE         RORAIMA   OLEO DIESEL S10
# 120819   2021-04-25 2021-05-01       SUL  SANTA CATARINA   OLEO DIESEL S10
# 120820   2021-04-25 2021-05-01   SUDESTE       SAO PAULO   OLEO DIESEL S10
# 120821   2021-04-25 2021-05-01  NORDESTE         SERGIPE   OLEO DIESEL S10
# 120822   2021-04-25 2021-05-01     NORTE       TOCANTINS   OLEO DIESEL S10
#
# ...

# %% [markdown]
# ### Alternativa - 3 Usando query()

# %%
lista_anos
# Out:
# [2017, 2019, 2021]

# %%
busca = data.query('ANO in @lista_anos')
busca
# Out:
#        DATA INICIAL DATA FINAL    REGIÃO          ESTADO           PRODUTO  \
# 87256    2017-01-01 2017-01-07     NORTE            ACRE  ETANOL HIDRATADO
# 87257    2017-01-01 2017-01-07  NORDESTE         ALAGOAS  ETANOL HIDRATADO
# 87258    2017-01-01 2017-01-07     NORTE           AMAPA  ETANOL HIDRATADO
# 87259    2017-01-01 2017-01-07     NORTE        AMAZONAS  ETANOL HIDRATADO
# 87260    2017-01-01 2017-01-07  NORDESTE           BAHIA  ETANOL HIDRATADO
# ...             ...        ...       ...             ...               ...
# 120818   2021-04-25 2021-05-01     NORTE         RORAIMA   OLEO DIESEL S10
# 120819   2021-04-25 2021-05-01       SUL  SANTA CATARINA   OLEO DIESEL S10
# 120820   2021-04-25 2021-05-01   SUDESTE       SAO PAULO   OLEO DIESEL S10
# 120821   2021-04-25 2021-05-01  NORDESTE         SERGIPE   OLEO DIESEL S10
# 120822   2021-04-25 2021-05-01     NORTE       TOCANTINS   OLEO DIESEL S10
#
# ...

# %% [markdown]
# ## Iterando com DataFrames
# For-each() DataFrame.iterrows() ( LENTO ==> apenas indicado para iterar pequenos conjuntos de dados )

# %%
for index, row in data.head(10).iterrows():
    print(f"indice {index} ==> {row['ESTADO']}")
# Out:
# indice 0 ==> DISTRITO FEDERAL
# indice 1 ==> GOIAS
# indice 2 ==> MATO GROSSO
# indice 3 ==> MATO GROSSO DO SUL
# indice 4 ==> ALAGOAS
# indice 5 ==> BAHIA
# indice 6 ==> CEARA
# indice 7 ==> MARANHAO
# indice 8 ==> PARAIBA
# indice 9 ==> PERNAMBUCO

# %% [markdown]
# ## Preparação de Dados
# Iremos aprender algumas técnicas de limpeza de dados para o DataFrame

# %%
data
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE             ALAGOAS
# ...             ...        ...           ...                 ...
# 120818   2021-04-25 2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25 2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25 2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25 2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25 2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ### Tratando observações com valores vazios (null / nan) no dataset
# Podemos usar o método **.info()** para mostrar informações sobre o dataset para melhor compreensão

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[us]
#  1   DATA FINAL                     120823 non-null  datetime64[us]
#  2   REGIÃO                         120823 non-null  str
#  3   ESTADO                         120823 non-null  str
#  4   PRODUTO                        120823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  str
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  str
# ...

# %% [markdown]
# Em uma primeira análise utilizando **data.info()**, somos sugestionados a entender que não existem valores **non-null** no dataset, mas será que isso é realmente verdade ? Temos que aplicar outras técnicas para confirmar essa informação.

# %% [markdown]
# ### Conversão de tipos de atributos
# Algumas colunas de nosso dataset estão com os valores como **str** em vez de serem corretamente classificados como float64, como podemos visualizar para as colunas **MARGEM MÉDIA REVENDA**, **DESVIO PADRÃO DISTRIBUIÇÃO**, **PREÇO MÍNIMO DISTRIBUIÇÃO**, **PREÇO MÁXIMO DISTRIBUIÇÃO** e **COEF DE VARIAÇÃO DISTRIBUIÇÃO**.
# Note que a parte de conversão da **DATA INICIAL** e **DATA FINAL** já estão com o tipo correto que é datetime64[us], entretanto também iremos converter o mesmo para o padrão brasileiro no formato dia / mês / ano(xxxx), fizemos a conversão anteriormente para gerar a coluna **ANO**.
# Para realizarmos limpeza e depuração dos dados é essencial realizarmos uma cópia de nosso DataFrame.

# %%
data_pre = data.copy()

# %% [markdown]
# ### Conversão de **DATAS**

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'], format='%d/%m/%Y')
#data_pre['DATA INICIAL'] = data_pre['DATA INICIAL'].dt.strftime('%d-%m-%Y')
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'], format='%d/%m/%Y')
#data_pre['DATA FINAL'] = data_pre['DATA FINAL'].dt.strftime('%d-%m-%Y')
data_pre.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[us]
#  1   DATA FINAL                     120823 non-null  datetime64[us]
#  2   REGIÃO                         120823 non-null  str
#  3   ESTADO                         120823 non-null  str
#  4   PRODUTO                        120823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  str
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  str
# ...

# %% [markdown]
# ### Conversão dados Numéricos

# %%
# convertendo colunas / atributos para numeric
lista_conversao = [ 'MARGEM MÉDIA REVENDA', 'DESVIO PADRÃO DISTRIBUIÇÃO',
                    'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']
for coluna in lista_conversao:
    # converte os valores da coluna para um tipo numérico
    # Em caso de erro na conversão será atributo na str um valor NAN
    data_pre[coluna] = pd.to_numeric(data_pre[coluna], errors = 'coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[us]
#  1   DATA FINAL                     120823 non-null  datetime64[us]
#  2   REGIÃO                         120823 non-null  str
#  3   ESTADO                         120823 non-null  str
#  4   PRODUTO                        120823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  str
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           117392 non-null  float64
# ...

# %% [markdown]
# ### Limpeza de dados

# %%
# adiciona na variável null a lista de booleanos e diz se é null ou não
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Observar no dataset original quais são os objetos que agora estão sendo classificados no NaN para o PREÇO MÉDIO DISTRIBUIÇÃO

# %%
data[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Descobrimos que no dataset original os dados foram preenchidos com setas e também NaN, o que impede de mostrar o objeto correto.
# Podemos tentar colocar valores na coluna PREÇO MÉDIO DISTRIBUIÇÃO ou deixar com um valor que não atrapalhe a análise.
# Podemos preencher com um valor padrão , utilizando o método **.fillna**.

# %%
# Retorna uma cópia do data frame 'data_pre' com todos os valores NaN, de todas as colunas , agora preenchidas
# com 0.
# Para alterar o próprio data_pre , colocar o argumento inplace=True
data_pre_fill = data_pre.fillna(0)

# %%
# Valores que NaN agora são 0
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### Atenção:
# O método **.fillna** é bem poderoso e com ele podemos especificar valores constantes para cada uma de nossas colunas no dataset.

# %%
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10, 
    'MARGEM MÉDIA REVENDA': 0.00, 
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20, 
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30, 
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio',
    'COEF DE VARIAÇÃO DISTRIBUIÇÃO': 'nops'
})
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Para a nossa análise o melhor para esse dataset , pensando na qualidade dos dados é dar um **.dropna()**

# %%
# remove no próprio DataFrame, todas as linhas que forem do tipo NaN em qualquer coluna
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 117392 entries, 0 to 120822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   117392 non-null  datetime64[us]
#  1   DATA FINAL                     117392 non-null  datetime64[us]
#  2   REGIÃO                         117392 non-null  str
#  3   ESTADO                         117392 non-null  str
#  4   PRODUTO                        117392 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   117392 non-null  int64
#  6   UNIDADE DE MEDIDA              117392 non-null  str
#  7   PREÇO MÉDIO REVENDA            117392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          117392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           117392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           117392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           117392 non-null  float64
# ...

# %% [markdown]
# Essa foi a nossa introdução básica sobre limpeza de dados, não iremos abordar por enquanto os outliers e outras técnicas mais avançadas.

# %% [markdown]
# ### Salvando o Dataset Preprocessado

# %%
data_pre.to_csv('./datasets/GasPriceBrazil-2004-2021_preprocessado_final.csv', index=False)

# %% [markdown]
# ## Estatísticas Descritivas

# %%
data_final = pd.read_csv('./datasets/GasPriceBrazil-2004-2021_preprocessado_final.csv')

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 117387   2021-04-25  2021-05-01         NORTE             RORAIMA
# 117388   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 117389   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 117390   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 117391   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# O pandas fornece algumas estatísticas descritivas, tais como o método **.describe()** que exibe várias estatísticas descritivas para os atributos de um dataframe ou para uma Series

# %%
data_final.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 117392.000000        117392.000000
# mean                     226.632190            11.415039
# std                      392.042029            19.149383
# min                        1.000000             0.766000
# 25%                       42.000000             2.159000
# 50%                      102.000000             2.915000
# 75%                      229.250000             4.023000
# max                     4167.000000           107.500000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          117392.000000         117392.000000         117392.000000
# mean                0.680834              9.922806             13.184631
# std                 1.402620             16.418908             22.465797
# min                 0.000000              0.590000              0.999000
# 25%                 0.076000              1.990000              2.440000
# ...

# %% [markdown]
# O método describe() retorna um dataframe então podemos filtrar apenas algumas colunas

# %%
filtro_desvio_padrao_revenda = data_final.describe()['DESVIO PADRÃO REVENDA']
filtro_desvio_padrao_revenda
# Out:
# count    117392.000000
# mean          0.680834
# std           1.402620
# min           0.000000
# 25%           0.076000
# 50%           0.121000
# 75%           0.203000
# max          10.748000
# Name: DESVIO PADRÃO REVENDA, dtype: float64

# %% [markdown]
# O método describe() também pode mostrar informações apenas de uma única coluna do dataframe

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    117392.000000
# mean         11.415039
# std          19.149383
# min           0.766000
# 25%           2.159000
# 50%           2.915000
# 75%           4.023000
# max         107.500000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = ['DESVIO PADRÃO REVENDA','PREÇO MÍNIMO REVENDA','PREÇO MÁXIMO REVENDA']
stats
estatistica = data_final.describe()
estatistica[stats]
# Out:
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count          117392.000000         117392.000000         117392.000000
# mean                0.680834              9.922806             13.184631
# std                 1.402620             16.418908             22.465797
# min                 0.000000              0.590000              0.999000
# 25%                 0.076000              1.990000              2.440000
# 50%                 0.121000              2.699000              3.240000
# 75%                 0.203000              3.780000              4.580000
# max                10.748000            100.000000            120.000000

# %% [markdown]
# Abaixo temos uma forma mais rápida de fazer

# %%
data_final[stats].describe()
# Out:
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count          117392.000000         117392.000000         117392.000000
# mean                0.680834              9.922806             13.184631
# std                 1.402620             16.418908             22.465797
# min                 0.000000              0.590000              0.999000
# 25%                 0.076000              1.990000              2.440000
# 50%                 0.121000              2.699000              3.240000
# 75%                 0.203000              3.780000              4.580000
# max                10.748000            100.000000            120.000000

# %% [markdown]
# ### Acessando apenas algumas estatísticas

# %%
estatistica
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 117392.000000        117392.000000
# mean                     226.632190            11.415039
# std                      392.042029            19.149383
# min                        1.000000             0.766000
# 25%                       42.000000             2.159000
# 50%                      102.000000             2.915000
# 75%                      229.250000             4.023000
# max                     4167.000000           107.500000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          117392.000000         117392.000000         117392.000000
# mean                0.680834              9.922806             13.184631
# std                 1.402620             16.418908             22.465797
# min                 0.000000              0.590000              0.999000
# 25%                 0.076000              1.990000              2.440000
# ...

# %% [markdown]
# Podemos passar apenas os rótulos para acessar as estatísticas desejadas.

# %%
estatistica.loc[['mean', 'min', 'max']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# mean                     226.63219            11.415039
# min                        1.00000             0.766000
# max                     4167.00000           107.500000
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# mean               0.680834              9.922806             13.184631
# min                0.000000              0.590000              0.999000
# max               10.748000            100.000000            120.000000
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# mean          -4697.376395                  0.045586
# min          -99999.000000                  0.000000
# max              36.847000                  0.262000
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# mean              -4683.425711                -4691.371824
# min              -99999.000000               -99999.000000
# ...

# %%
# Selecionando apenas para o PREÇO MÉDIO REVENDA -> retorna uma Series
estatistica.loc[['mean', 'min', 'max'], 'PREÇO MÉDIO REVENDA']
# Out:
# mean     11.415039
# min       0.766000
# max     107.500000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
# Podemos selecionar mais de uma coluna 
estatistica.loc[['mean', 'min', 'max'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# mean            11.415039              -4683.425711
# min              0.766000             -99999.000000
# max            107.500000                 83.137000

# %% [markdown]
# ### Atenção:
# Cada uma das estatísticas que estão no método **.describe()**, pode ser computada individualmente

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data_final['PREÇO MÉDIO REVENDA'].min()
# Out:
# np.float64(0.7659999999999999)

# %% [markdown]
# ### Qual a média e desvio padrão dos preços mínimos de revenda?

# %%
media = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {media:.3f} com desvio padrão de  +- {std:.3f}')
# Out:
# A média dos preços mínimos de revenda é 9.923 com desvio padrão de  +- 16.419

# %% [markdown]
# ### Quais são os estados considerados nessa análise ?

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# ### Quantos registros (aferições) cada estado possui ?

# %% [markdown]
# .value_counts(): Conta a frequência dos valores de uma dada variável ( de preferência, categórica ).

# %%
# retorna em ordem decrescente , a quantidade de registros / linhas para cada estado
data_final['ESTADO'].value_counts()
# Out:
# ESTADO
# BAHIA                  4819
# RIO DE JANEIRO         4818
# SAO PAULO              4817
# RIO GRANDE DO SUL      4805
# PARAIBA                4796
# PERNAMBUCO             4787
# SERGIPE                4738
# SANTA CATARINA         4720
# MINAS GERAIS           4698
# ESPIRITO SANTO         4634
# MATO GROSSO DO SUL     4623
# ALAGOAS                4576
# RIO GRANDE DO NORTE    4555
# CEARA                  4514
# PARANA                 4458
# AMAZONAS               4238
# MATO GROSSO            4232
# MARANHAO               3942
# PARA                   3935
# ACRE                   3931
# RORAIMA                3924
# TOCANTINS              3923
# GOIAS                  3920
# RONDONIA               3912
# PIAUI                  3863
# DISTRITO FEDERAL       3790
# AMAPA                  3424
# Name: count, dtype: int64

# %% [markdown]
# Para converter essa SERIES para um DataFrame, usamos o método **.to_frame()**

# %%
data_final['ESTADO'].value_counts().to_frame()
# Out:
#                      count
# ESTADO
# BAHIA                 4819
# RIO DE JANEIRO        4818
# SAO PAULO             4817
# RIO GRANDE DO SUL     4805
# PARAIBA               4796
# PERNAMBUCO            4787
# SERGIPE               4738
# SANTA CATARINA        4720
# MINAS GERAIS          4698
# ESPIRITO SANTO        4634
# MATO GROSSO DO SUL    4623
# ALAGOAS               4576
# RIO GRANDE DO NORTE   4555
# CEARA                 4514
# PARANA                4458
# AMAZONAS              4238
# MATO GROSSO           4232
# MARANHAO              3942
# PARA                  3935
# ACRE                  3931
# RORAIMA               3924
# TOCANTINS             3923
# GOIAS                 3920
# RONDONIA              3912
# PIAUI                 3863
# DISTRITO FEDERAL      3790
# AMAPA                 3424

# %% [markdown]
# Renomeando para FREQUÊNCIA

# %%
# Forma para a frequência relativa
data_final['ESTADO'].value_counts(normalize=True).to_frame('FREQUÊNCIA')
# Out:
#                      FREQUÊNCIA
# ESTADO
# BAHIA                  0.041050
# RIO DE JANEIRO         0.041042
# SAO PAULO              0.041033
# RIO GRANDE DO SUL      0.040931
# PARAIBA                0.040855
# PERNAMBUCO             0.040778
# SERGIPE                0.040361
# SANTA CATARINA         0.040207
# MINAS GERAIS           0.040020
# ESPIRITO SANTO         0.039475
# MATO GROSSO DO SUL     0.039381
# ALAGOAS                0.038981
# RIO GRANDE DO NORTE    0.038802
# CEARA                  0.038452
# PARANA                 0.037975
# AMAZONAS               0.036101
# MATO GROSSO            0.036050
# MARANHAO               0.033580
# PARA                   0.033520
# ACRE                   0.033486
# RORAIMA                0.033426
# TOCANTINS              0.033418
# GOIAS                  0.033392
# RONDONIA               0.033324
# PIAUI                  0.032907
# DISTRITO FEDERAL       0.032285
# AMAPA                  0.029167

# %% [markdown]
# Frequência absoluta e relativa

# %%
vc = data_final['ESTADO'].value_counts()
freq = data_final['ESTADO'].value_counts(normalize=True)
pd.concat([vc.rename('FREQUÊNCIA ABSOLUTA'), freq.rename('FREQUÊNCIA RELATIVA')], axis=1)
# Out:
#                      FREQUÊNCIA ABSOLUTA  FREQUÊNCIA RELATIVA
# ESTADO
# BAHIA                               4819             0.041050
# RIO DE JANEIRO                      4818             0.041042
# SAO PAULO                           4817             0.041033
# RIO GRANDE DO SUL                   4805             0.040931
# PARAIBA                             4796             0.040855
# PERNAMBUCO                          4787             0.040778
# SERGIPE                             4738             0.040361
# SANTA CATARINA                      4720             0.040207
# MINAS GERAIS                        4698             0.040020
# ESPIRITO SANTO                      4634             0.039475
# MATO GROSSO DO SUL                  4623             0.039381
# ALAGOAS                             4576             0.038981
# RIO GRANDE DO NORTE                 4555             0.038802
# CEARA                               4514             0.038452
# ...
